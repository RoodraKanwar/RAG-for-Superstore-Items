# %%
import pandas as pd
from collections import Counter

# %% [markdown]
# # Reading and cleaning dataset

# %%
df = pd.read_csv("/content/grocery_data_mar_2025.csv")

# %%
df.columns
# Out:
# Index(['productId', 'productImage', 'brand', 'title', 'description',
#        'packageSizing', 'deal', 'mopDeal', 'pcoDeal', 'inventoryIndicator',
#        'offerType', 'offerId', 'action', 'isVariant', 'link', 'productVendor',
#        'productVariant', 'textBadge', 'variantTheme', 'articleNumber', 'uom',
#        'sponsoredCreative', 'isSponsored', 'isComplementarySponsored',
#        'complementarySponsoredBadgeText', 'productBadge', 'pricing.price',
#        'pricing.wasPrice', 'pricing.displayPrice', 'pricing.memberOnlyPrice',
#        'pricing.mopDisplayPrice', 'pricing.ehfTotal',
#        'pricing.environmentalHandlingFee', 'pricingUnits.type',
#        'pricingUnits.unit', 'pricingUnits.interval',
#        'pricingUnits.minOrderQuantity', 'pricingUnits.maxOrderQuantity',
#        'pricingUnits.weighted', 'deal.type', 'deal.text', 'deal.points',
#        'deal.name', 'deal.expiryDate', 'deal.dealPrice',
#        'inventoryIndicator.indicatorId', 'inventoryIndicator.text',
#        'productBadge.badgeId', 'productBadge.badgeClass', 'productBadge.text',
#        'productBadge.icon', 'productBadge.icon.url',
#        'productBadge.icon.altText', 'productBadge.icon.placement',
#        'pricing.environmentalHandlingFee.carbonFee',
#        'pricing.environmentalHandlingFee.ecologyFee',
#        'pricing.environmentalHandlingFee.electronicFee',
#        'pricing.environmentalHandlingFee.hazardousFee'],
#       dtype='object')

# %%
df = df[['brand','title','packageSizing','pricing.price']]

# %% [markdown]
# ### Converting column values

# %%
df = df.copy()
df["title"] = df["title"].str.lower()
df['brand'] = df['brand'].str.lower()
df['pricing.price'] = df['pricing.price'].astype(float)
df = df.drop_duplicates()
df
# Out:
#                       brand  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                   rooster
# ...                     ...
# 10021  wholesome sweeteners
# 10022                   a&w
# 10024              castello
# 10025                   NaN
# 10028    president's choice
#
#                                                    title  \
# 0                                          roma tomatoes
# 1                                               cilantro
# 2                                                  mango
# 3                                                 ginger
# 4                                  garlic bulbs, 3-count
# ...                                                  ...
# 10021                 whole organic raw blue agave syrup
# 10022                                 diet root beer
# 10024         cream cheese spread, sweet & spicy peppers
# 10025                        jelly crystals, mixed fruit
# 10028  dark sweet cherries, blueberries and blackberr...
#
#                   packageSizing  pricing.price
# 0           $7.69/1kg $3.49/1lb           0.92
# 1               1 ea, $0.99/1ea           0.50
# 2               1 ea, $1.49/1ea           1.49
# 3           $3.26/1kg $1.48/1lb           0.68
# 4               90 g, $0.33/1ea           1.00
# ...                         ...            ...
# 10021       480 ml, $2.08/100ml           9.99
# 10022  12x355.0 ml, $0.19/100ml           6.99
# 10024         125 g, $4.00/100g           5.00
# 10025          90 g, $1.43/100g           1.29
# 10028         600 g, $0.92/100g           4.99
#
# [7493 rows x 4 columns]

# %% [markdown]
# ### Splitting packageSizing into Item size and Cost per unit
#
# - Further split cost per unit into the price amount and the unit metric

# %%
# Function to split based on ',' if present, otherwise split on whitespace
def custom_split(value):
    if ',' in value:
        return value.split(',', 1)  # Split on first comma
    else:
        return value.split(maxsplit=1)  # Split on first whitespace

# Apply the function and expand into two new columns
df[['item_total_sizing', 'cost_per_unit']] = df['packageSizing'].apply(lambda x: pd.Series(custom_split(x)))
df[['price_amount', 'price_unit']] = df['cost_per_unit'].str.extract(r'\$([\d.]+)\/(\S+)')
df
# Out:
#                       brand  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                   rooster
# ...                     ...
# 10021  wholesome sweeteners
# 10022                   a&w
# 10024              castello
# 10025                   NaN
# 10028    president's choice
#
#                                                    title  \
# 0                                          roma tomatoes
# 1                                               cilantro
# 2                                                  mango
# 3                                                 ginger
# 4                                  garlic bulbs, 3-count
# ...                                                  ...
# 10021                 whole organic raw blue agave syrup
# 10022                                 diet root beer
# 10024         cream cheese spread, sweet & spicy peppers
# 10025                        jelly crystals, mixed fruit
# 10028  dark sweet cherries, blueberries and blackberr...
#
#                   packageSizing  pricing.price item_total_sizing  \
# 0           $7.69/1kg $3.49/1lb           0.92         $7.69/1kg
# 1               1 ea, $0.99/1ea           0.50              1 ea
# 2               1 ea, $1.49/1ea           1.49              1 ea
# 3           $3.26/1kg $1.48/1lb           0.68         $3.26/1kg
# 4               90 g, $0.33/1ea           1.00              90 g
# ...                         ...            ...               ...
# 10021       480 ml, $2.08/100ml           9.99            480 ml
# 10022  12x355.0 ml, $0.19/100ml           6.99       12x355.0 ml
# 10024         125 g, $4.00/100g           5.00             125 g
# 10025          90 g, $1.43/100g           1.29              90 g
# 10028         600 g, $0.92/100g           4.99             600 g
#
#       cost_per_unit price_amount price_unit
# 0         $3.49/1lb         3.49        1lb
# 1         $0.99/1ea         0.99        1ea
# 2         $1.49/1ea         1.49        1ea
# 3         $1.48/1lb         1.48        1lb
# 4         $0.33/1ea         0.33        1ea
# ...             ...          ...        ...
# 10021   $2.08/100ml         2.08      100ml
# 10022   $0.19/100ml         0.19      100ml
# 10024    $4.00/100g         4.00       100g
# 10025    $1.43/100g         1.43       100g
# 10028    $0.92/100g         0.92       100g
#
# [7493 rows x 8 columns]

# %% [markdown]
# ### Renaming the column for better understanding by the Gemini Model

# %%
df = df.rename(columns={
    'title': 'product_name',
    'packageSizing': 'size_options',
    'pricing.price': 'base_price',
    'item_total_sizing': 'product_size',
    'cost_per_unit': 'price_per_unit',
    'price_amount': 'unit_price_value',
    'price_unit': 'unit_measure'
})
df = df.drop(columns=['size_options'])

# %% [markdown]
# #### Converting columns to numeric column type and check the `dtypes` of columns

# %%
df['base_price'] = pd.to_numeric(df['base_price'])
df['unit_price_value'] = pd.to_numeric(df['unit_price_value'])
df.dtypes
# Out:
# brand                object
# product_name         object
# base_price          float64
# product_size         object
# price_per_unit       object
# unit_price_value    float64
# unit_measure         object
# dtype: object

# %%
df.head(5)
# Out:
#      brand           product_name  base_price product_size price_per_unit  \
# 0      NaN          roma tomatoes        0.92    $7.69/1kg      $3.49/1lb
# 1      NaN               cilantro        0.50         1 ea      $0.99/1ea
# 2      NaN                  mango        1.49         1 ea      $1.49/1ea
# 3      NaN                 ginger        0.68    $3.26/1kg      $1.48/1lb
# 4  rooster  garlic bulbs, 3-count        1.00         90 g      $0.33/1ea
#
#    unit_price_value unit_measure
# 0              3.49          1lb
# 1              0.99          1ea
# 2              1.49          1ea
# 3              1.48          1lb
# 4              0.33          1ea

# %% [markdown]
# #### Top 20 brand names present in the dataset

# %%
df['brand'].value_counts().head(20)
# Out:
# brand
# president's choice    781
# no name               353
# pc organics           136
# pc blue menu           83
# club house             69
# farmer's market        62
# suraj                  59
# christie               59
# t&t                    51
# nestlé                 50
# kelloggs               48
# kraft                  47
# lindt                  45
# betty crocker          43
# ziggy's                40
# chapmans               39
# campbell's             38
# haldiram               37
# pc black label         37
# knorr                  37
# Name: count, dtype: int64

# %% [markdown]
# #### Functions used in data cleaning

# %%
# Returns a DataFrame containing the searched word, sorted by the `base_price`
def food_item(w):
  curated_item_df = df[df['product_name'].str.contains(w, case=False, na=False)]
  curated_item_df = curated_item_df.sort_values(by='base_price')

  return curated_item_df

# Returns the word count for the words present in the DataFrame under the `product_name` column
def word_counts(tf):
  words = tf['product_name'].str.split()
  all_words = [word.lower() for sublist in words for word in sublist]

  word_counts = Counter(all_words)
  word_counts_df = pd.DataFrame(word_counts.items(), columns=['Word', 'Count']).sort_values(by='Count', ascending=False)

  return word_counts_df

# Returns rows from the DataFrame where the 'brand' column contains any of the words in the word list
def exclude_brand_rows(df, word_list):
  pattern = '|'.join(word_list)
  filtered_df = df[~df['brand'].str.contains(pattern, case=False, na=False)]

  return filtered_df

# Returns rows from the DataFrame where the 'product_name' column contains any of the words in the word list
def exclude_product_rows(df, word_list):
  pattern = '|'.join(word_list)
  filtered_df = df[~df['product_name'].str.contains(pattern, case=False, na=False)]

  return filtered_df

# Returns rows from the DataFrame where the 'product_name' column contains any of the words in the word list
def include_product_rows(df, word_list, item_name):
  pattern = '|'.join(word_list)
  filtered_df = df[df['product_name'].str.contains(pattern, case=False, na=False)]
  filtered_df = filtered_df.copy()
  filtered_df['item'] = item_name

  return filtered_df

# Returns two DataFrames vertically (row-wise) and resets the index.
def combine_dataframes(df1, df2):
  df1 = df1.reset_index(drop=True)
  df2 = df2.reset_index(drop=True)

  # Combine vertically and ignore original indices
  combined_df = pd.concat([df1, df2], axis=0, ignore_index=True)

  return combined_df

# %% [markdown]
# #### Brand Removal which are not useful for this use case

# %%
word_list = ['lindt','betty crocker', 'chapmans', 'nestl', 'campbell', 'haldiram', 'knorr', 'starbucks', 'cadbury', 'hershey', 'kinder', 'kraft', 'johnvince foods',
             'general mills', 'burt', 'tim hortons', 'club house', 'kraft']

df = exclude_brand_rows(df, word_list)
df
# Out:
#                       brand  \
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                   rooster
# ...                     ...
# 10021  wholesome sweeteners
# 10022                   a&w
# 10024              castello
# 10025                   NaN
# 10028    president's choice
#
#                                             product_name  base_price  \
# 0                                          roma tomatoes        0.92
# 1                                               cilantro        0.50
# 2                                                  mango        1.49
# 3                                                 ginger        0.68
# 4                                  garlic bulbs, 3-count        1.00
# ...                                                  ...         ...
# 10021                 whole organic raw blue agave syrup        9.99
# 10022                                 diet root beer            6.99
# 10024         cream cheese spread, sweet & spicy peppers        5.00
# 10025                        jelly crystals, mixed fruit        1.29
# 10028  dark sweet cherries, blueberries and blackberr...        4.99
#
#       product_size price_per_unit  unit_price_value unit_measure
# 0        $7.69/1kg      $3.49/1lb              3.49          1lb
# 1             1 ea      $0.99/1ea              0.99          1ea
# 2             1 ea      $1.49/1ea              1.49          1ea
# 3        $3.26/1kg      $1.48/1lb              1.48          1lb
# 4             90 g      $0.33/1ea              0.33          1ea
# ...            ...            ...               ...          ...
# 10021       480 ml    $2.08/100ml              2.08        100ml
# 10022  12x355.0 ml    $0.19/100ml              0.19        100ml
# 10024        125 g     $4.00/100g              4.00         100g
# 10025         90 g     $1.43/100g              1.43         100g
# 10028        600 g     $0.92/100g              0.92         100g
#
# [6864 rows x 7 columns]

# %% [markdown]
# # Food Items

# %% [markdown]
# #### 1. Eggs

# %%
word = 'egg'
eggs_df = food_item(word)
eggs_df
# Out:
#             brand                                       product_name  \
# 2857          t&t                            chinese pastry with egg
# 2942      sunrype  fruitsource apple wildberry carrot 100% fruit ...
# 1082        monde                                     eggnog cookies
# 8539      rooster                          thick  shrimp egg noodles
# 20            NaN                                   purple eggplants
# ...           ...                                                ...
# 2736    tuscanini            kosher premium pizza, grilled veggie
# 9738          NaN                              veggie tray, tri-pack
# 9769          NaN  veggie platter, small (broccoli, carrots, mini...
# 3644   jean talon                                      lol super egg
# 598   pc organics  free-range large brown eggs, club pack (30 count)
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 2857        0.99        228 g     $0.43/100g              0.43         100g
# 2942        1.69         37 g     $4.57/100g              4.57         100g
# 1082        1.79        130 g     $1.38/100g              1.38         100g
# 8539        2.29        454 g     $0.50/100g              0.50         100g
# 20          2.47    $4.34/1kg      $1.97/1lb              1.97          1lb
# ...          ...          ...            ...               ...          ...
# 2736       11.99        425 g     $2.82/100g              2.82         100g
# 9738       12.00      1.01 kg     $1.19/100g              1.19         100g
# 9769       14.00        962 g     $1.46/100g              1.46         100g
# 3644       14.99        150 g     $9.99/100g              9.99         100g
# 598        16.99        30 ea      $0.57/1ea              0.57          1ea
#
# [103 rows x 7 columns]

# %%
eggs_df['brand'].value_counts().head(10)
# Out:
# brand
# kelloggs              9
# sensible portions     6
# no name               6
# president's choice    6
# yves                  6
# burnbrae farms        5
# pc blue menu          4
# pc organics           4
# sau tao               3
# dare                  3
# Name: count, dtype: int64

# %% [markdown]
# #### Brand Removal for eggs which are not useful

# %%
brand_list = ['cadbury', 'kinder', 'lindt', 'hershey', 'rooster', 't&t', 'hellman','kellogg','reese','veeba']
eggs_df = exclude_brand_rows(eggs_df, brand_list)

# %%
eggs_df
# Out:
#             brand                                       product_name  \
# 2942      sunrype  fruitsource apple wildberry carrot 100% fruit ...
# 1082        monde                                     eggnog cookies
# 20            NaN                                   purple eggplants
# 3489         dare                        sour jelly eggs, spring mix
# 8466         dare                                breton veggie bites
# ...           ...                                                ...
# 2736    tuscanini            kosher premium pizza, grilled veggie
# 9738          NaN                              veggie tray, tri-pack
# 9769          NaN  veggie platter, small (broccoli, carrots, mini...
# 3644   jean talon                                      lol super egg
# 598   pc organics  free-range large brown eggs, club pack (30 count)
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 2942        1.69         37 g     $4.57/100g              4.57         100g
# 1082        1.79        130 g     $1.38/100g              1.38         100g
# 20          2.47    $4.34/1kg      $1.97/1lb              1.97          1lb
# 3489        2.49        225 g     $1.11/100g              1.11         100g
# 8466        2.49        200 g     $1.75/100g              1.75         100g
# ...          ...          ...            ...               ...          ...
# 2736       11.99        425 g     $2.82/100g              2.82         100g
# 9738       12.00      1.01 kg     $1.19/100g              1.19         100g
# 9769       14.00        962 g     $1.46/100g              1.46         100g
# 3644       14.99        150 g     $9.99/100g              9.99         100g
# 598        16.99        30 ea      $0.57/1ea              0.57          1ea
#
# [87 rows x 7 columns]

# %% [markdown]
# #### Checking the count of words present in `product_name`

# %%
eggs_word_df = word_counts(eggs_df)
eggs_word_df.head(10)
# Out:
#        Word  Count
# 7    veggie     32
# 26      egg     24
# 15    eggs,     13
# 64        &     13
# 45     eggs     12
# 54    large     10
# 79    white      8
# 85     with      7
# 29   garden      6
# 57  veggies      6

# %% [markdown]
# ### Word Removal

# %%
word_list = ['veggie','chocolate','cocoa','easter','filling','waffle','noodles','eggnog','wrap','breakfast','salad','mayo','eggplant','jelly','candy','pickle']
eggs_df = exclude_product_rows(eggs_df, word_list)
eggs_df
# Out:
#                brand                                       product_name  \
# 2104    pc blue menu  blue menu peeled hard boiled omega-3 free run ...
# 9003            kosa                                quail eggs in water
# 889          no name                                       eggs, medium
# 2915         no name                                        eggs, large
# 5859    pc blue menu                                free run egg whites
# 3362         no name                           grade a large brown eggs
# 1606  burnbrae farms                         naturegg simply egg whites
# 2506  burnbrae farms                            egg creations, original
# 4784  burnbrae farms               naturegg nest laid white eggs, large
# 7356   golden valley                           born 3 white eggs, large
# 5870  burnbrae farms                 naturegg omega 3 white eggs, large
# 4932     pc organics                      organic free-range egg whites
# 1452  burnbrae farms       egg bites! mini crustless quiches snack size
# 3688   golden valley                            white eggs, extra large
# 9714    rabbit river                        free run omega 3 brown eggs
# 580       hsu fu chi              chinese style pastry sachima with egg
# 8381    pc blue menu        blue menu free run large white eggs 12 pack
# 5277        just egg                                     just egg plant
# 41       pc organics                        free range large brown eggs
# 5175    pc blue menu                                         egg whites
# 7909      marcangelo  marc angelo pork sausages with rapini and parm...
# 6955     pc organics             extra large size free-range brown eggs
# 6953         elman's                                bad boys spicy eggs
# 7217           mutti                    pasta sauce parmigiano reggiano
# 4815        just egg                                   plant -based egg
# 3644      jean talon                                      lol super egg
# 598      pc organics  free-range large brown eggs, club pack (30 count)
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 2104        3.39     3x88.0 g     $3.85/100g              3.85         100g
# 9003        3.99        425 g     $0.94/100g              0.94         100g
# 889         4.06        12 ea      $0.34/1ea              0.34          1ea
# 2915        4.16        12 ea      $0.35/1ea              0.35          1ea
# 5859        5.29        500 g     $1.06/100g              1.06         100g
# 3362        5.37        12 ea      $0.45/1ea              0.45          1ea
# 1606        5.39         1 ea    $1.08/100ml              1.08        100ml
# 2506        5.49        500 g     $1.10/100g              1.10         100g
# 4784        5.69        12 ea      $0.47/1ea              0.47          1ea
# 7356        5.99        12 ea      $0.50/1ea              0.50          1ea
# 5870        6.49        12 ea      $0.54/1ea              0.54          1ea
# 4932        6.49        500 g     $1.30/100g              1.30         100g
# 1452        6.75        336 g     $2.01/100g              2.01         100g
# 3688        7.07        18 ea      $0.39/1ea              0.39          1ea
# 9714        7.40        12 ea      $0.62/1ea              0.62          1ea
# 580         7.49        469 g     $1.60/100g              1.60         100g
# 8381        7.69        12 ea      $0.64/1ea              0.64          1ea
# 5277        7.99      56.75 g    $14.08/100g             14.08         100g
# 41          7.99        12 ea      $0.67/1ea              0.67          1ea
# 5175        7.99         1 kg     $0.80/100g              0.80         100g
# 7909        7.99        675 g     $1.18/100g              1.18         100g
# 6955        8.10        12 ea      $0.68/1ea              0.68          1ea
# 6953        8.99        225 g     $4.00/100g              4.00         100g
# 7217        9.99       660 ml    $1.51/100ml              1.51        100ml
# 4815       10.49        500 g     $2.10/100g              2.10         100g
# 3644       14.99        150 g     $9.99/100g              9.99         100g
# 598        16.99        30 ea      $0.57/1ea              0.57          1ea

# %%
eggs_df = eggs_df[eggs_df['product_size'].str.contains('ea')]

# %% [markdown]
# Final list for eggs

# %%
word_list = ['eggs, large', 'grade a large brown eggs', 'naturegg simply egg whites', 'white eggs, extra large', 'large brown eggs']
eggs_df = include_product_rows(eggs_df, word_list, 'eggs')
eggs_df
# Out:
#                brand                                       product_name  \
# 2915         no name                                        eggs, large
# 3362         no name                           grade a large brown eggs
# 1606  burnbrae farms                         naturegg simply egg whites
# 4784  burnbrae farms               naturegg nest laid white eggs, large
# 7356   golden valley                           born 3 white eggs, large
# 5870  burnbrae farms                 naturegg omega 3 white eggs, large
# 3688   golden valley                            white eggs, extra large
# 41       pc organics                        free range large brown eggs
# 598      pc organics  free-range large brown eggs, club pack (30 count)
#
#       base_price product_size price_per_unit  unit_price_value unit_measure  \
# 2915        4.16        12 ea      $0.35/1ea              0.35          1ea
# 3362        5.37        12 ea      $0.45/1ea              0.45          1ea
# 1606        5.39         1 ea    $1.08/100ml              1.08        100ml
# 4784        5.69        12 ea      $0.47/1ea              0.47          1ea
# 7356        5.99        12 ea      $0.50/1ea              0.50          1ea
# 5870        6.49        12 ea      $0.54/1ea              0.54          1ea
# 3688        7.07        18 ea      $0.39/1ea              0.39          1ea
# 41          7.99        12 ea      $0.67/1ea              0.67          1ea
# 598        16.99        30 ea      $0.57/1ea              0.57          1ea
#
#       item
# 2915  eggs
# 3362  eggs
# 1606  eggs
# 4784  eggs
# 7356  eggs
# 5870  eggs
# 3688  eggs
# 41    eggs
# 598   eggs

# %% [markdown]
# #### 2. Chicken

# %%
word = 'chicken'
chicken_df  = food_item(word)
chicken_df
# Out:
#                    brand                                       product_name  \
# 5694             no name                chicken flavour instant noodle soup
# 3642           lucky me!     instant noodle soup artificial chicken flavour
# 9397                bens  fast & fancy homestyle chicken flavour & wild ...
# 1574             no name                      condensed chicken noodle soup
# 9702              aylmer                                chicken noodle soup
# ...                  ...                                                ...
# 465   president's choice  club pack fully cooked buttermilk chicken brea...
# 4494             no name                seasoned chicken breasts club size
# 3386                 NaN                                split chicken wings
# 5891             no name       club pack chicken breasts, boneless skinless
# 6775                 NaN           chicken breast portion boneless skinless
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 5694        0.39         85 g     $0.46/100g              0.46         100g
# 3642        0.79         55 g     $1.44/100g              1.44         100g
# 9397        0.97        132 g     $1.43/100g              1.43         100g
# 1574        1.00       284 ml    $0.35/100ml              0.35        100ml
# 9702        1.00       284 ml    $0.42/100ml              0.42        100ml
# ...          ...          ...            ...               ...          ...
# 465        35.99      1.81 kg     $1.99/100g              1.99         100g
# 4494       38.99         2 kg     $1.95/100g              1.95         100g
# 3386       39.00         4 kg     $0.98/100g              0.98         100g
# 5891       39.99         2 kg     $2.00/100g              2.00         100g
# 6775       50.00         1 ea     $50.00/1ea             50.00          1ea
#
# [236 rows x 7 columns]

# %%
top_brands = chicken_df['brand'].value_counts().head(7).index.tolist()
word_list = ['knorr', 'ziggy', 'janes', 'swanson']
chicken_df = exclude_brand_rows(chicken_df, word_list)

# %%
chicken_df['brand'].value_counts()
# Out:
# brand
# president's choice    43
# no name               21
# zabiha halal          10
# pc blue menu          10
# swiss chalet           5
#                       ..
# freybe                 1
# kebab factory          1
# el monterey            1
# pinty's                1
# prime                  1
# Name: count, Length: 74, dtype: int64

# %%
chicken_word_df = word_counts(chicken_df)
chicken_word_df.head(20)
# Out:
#         Word  Count
# 0    chicken    222
# 7          &     22
# 106   breast     18
# 4       soup     17
# 3     noodle     15
# 152  breaded     14
# 193     club     14
# 186     pack     14
# 43      with     13
# 35    butter     12
# 1    flavour     11
# 294    wings     10
# 98    cooked      9
# 97     fully      9
# 119   frozen      8
# 49     sauce      8
# 42       mix      8
# 44     broth      8
# 131      and      7
# 233     free      7

# %%
word_list = ['soup','noodle','flavour','with','breaded','butter','cooked','fully','rice','broth','mix','style','frozen']
chicken_df = exclude_product_rows(chicken_df, word_list)

# %%
word_list = ['chicken sausages', 'extra lean ground chicken', 'halal whole chicken', 'club pack chicken thighs, bone-in', 'chicken wings, club pack', 'club pack chicken wings, split', 'club pack chicken breasts, boneless skinless']
chicken_df = include_product_rows(chicken_df, word_list, 'chicken')
chicken_df
# Out:
#              brand                                  product_name  base_price  \
# 7755  zabiha halal                              chicken sausages        6.99
# 3052         sufra                    extra lean ground chicken         8.00
# 6461         sufra                           halal whole chicken       14.00
# 7802       no name             club pack chicken thighs, bone-in       17.99
# 7180       no name         honey garlic chicken wings, club pack       26.50
# 7304       no name                      chicken wings, club pack       26.50
# 4782       no name                club pack chicken wings, split       26.99
# 5891       no name  club pack chicken breasts, boneless skinless       39.99
#
#      product_size price_per_unit  unit_price_value unit_measure     item
# 7755        375 g     $1.86/100g              1.86         100g  chicken
# 3052        454 g     $1.76/100g              1.76         100g  chicken
# 6461       1.7 kg     $0.82/100g              0.82         100g  chicken
# 7802         2 kg     $0.90/100g              0.90         100g  chicken
# 7180      1.81 kg     $1.46/100g              1.46         100g  chicken
# 7304      1.81 kg     $1.46/100g              1.46         100g  chicken
# 4782         2 kg     $1.35/100g              1.35         100g  chicken
# 5891         2 kg     $2.00/100g              2.00         100g  chicken

# %% [markdown]
# Merging Eggs and Chicken dataframe

# %%
final_df = combine_dataframes(eggs_df, chicken_df)
final_df
# Out:
#              brand                                       product_name  \
# 0          no name                                        eggs, large
# 1          no name                           grade a large brown eggs
# 2   burnbrae farms                         naturegg simply egg whites
# 3   burnbrae farms               naturegg nest laid white eggs, large
# 4    golden valley                           born 3 white eggs, large
# 5   burnbrae farms                 naturegg omega 3 white eggs, large
# 6    golden valley                            white eggs, extra large
# 7      pc organics                        free range large brown eggs
# 8      pc organics  free-range large brown eggs, club pack (30 count)
# 9     zabiha halal                                   chicken sausages
# 10           sufra                         extra lean ground chicken
# 11           sufra                                halal whole chicken
# 12         no name                  club pack chicken thighs, bone-in
# 13         no name              honey garlic chicken wings, club pack
# 14         no name                           chicken wings, club pack
# 15         no name                     club pack chicken wings, split
# 16         no name       club pack chicken breasts, boneless skinless
#
#     base_price product_size price_per_unit  unit_price_value unit_measure  \
# 0         4.16        12 ea      $0.35/1ea              0.35          1ea
# 1         5.37        12 ea      $0.45/1ea              0.45          1ea
# 2         5.39         1 ea    $1.08/100ml              1.08        100ml
# 3         5.69        12 ea      $0.47/1ea              0.47          1ea
# 4         5.99        12 ea      $0.50/1ea              0.50          1ea
# 5         6.49        12 ea      $0.54/1ea              0.54          1ea
# 6         7.07        18 ea      $0.39/1ea              0.39          1ea
# 7         7.99        12 ea      $0.67/1ea              0.67          1ea
# 8        16.99        30 ea      $0.57/1ea              0.57          1ea
# 9         6.99        375 g     $1.86/100g              1.86         100g
# 10        8.00        454 g     $1.76/100g              1.76         100g
# 11       14.00       1.7 kg     $0.82/100g              0.82         100g
# 12       17.99         2 kg     $0.90/100g              0.90         100g
# 13       26.50      1.81 kg     $1.46/100g              1.46         100g
# 14       26.50      1.81 kg     $1.46/100g              1.46         100g
# 15       26.99         2 kg     $1.35/100g              1.35         100g
# 16       39.99         2 kg     $2.00/100g              2.00         100g
#
#        item
# 0      eggs
# 1      eggs
# 2      eggs
# 3      eggs
# 4      eggs
# 5      eggs
# 6      eggs
# 7      eggs
# 8      eggs
# 9   chicken
# 10  chicken
# 11  chicken
# 12  chicken
# 13  chicken
# 14  chicken
# 15  chicken
# 16  chicken

# %% [markdown]
# #### 3. Pork

# %% [markdown]
# Taking food items having pork in `product_name` with `base_price` more than 5 as below it would consist of unuseful items

# %%
word = 'pork'
pork_df = df[df['product_name'].str.contains(word, case=False, na=False)]
pork_df = pork_df[pork_df['base_price'] >= 5]
pork_df = pork_df.sort_values(by='base_price')
pork_df
# Out:
#                    brand                                 product_name  \
# 5649                 t&t                      pork & leek potstickers
# 4163                 NaN                              cured salt pork
# 6284               siwin                                  pork tocino
# 3265  president's choice  pork & chicken liver pâté with black pepper
# 7774  president's choice                   free from lean ground pork
# ...                  ...                                          ...
# 6237                 NaN         lethbridge pork butt roast, boneless
# 4509          mitchell's                           pure pork sausages
# 40                   NaN                       pork back ribs, 2-pack
# 4651                 NaN         frozen pork bone-in half loin bagged
# 7733                 NaN                                 pork sirloin
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 5649        5.00        567 g     $0.88/100g              0.88         100g
# 4163        5.23   $19.82/1kg      $8.99/1lb              8.99          1lb
# 6284        5.49        375 g     $1.46/100g              1.46         100g
# 3265        5.49        150 g     $3.66/100g              3.66         100g
# 7774        5.49        454 g     $1.21/100g              1.21         100g
# ...          ...          ...            ...               ...          ...
# 6237       17.96   $17.61/1kg      $7.99/1lb              7.99          1lb
# 4509       22.99         2 kg     $1.15/100g              1.15         100g
# 40         33.22   $15.41/1kg      $6.99/1lb              6.99          1lb
# 4651       43.16    $8.80/1kg      $3.99/1lb              3.99          1lb
# 7733       47.05   $11.00/1kg      $4.99/1lb              4.99          1lb
#
# [61 rows x 7 columns]

# %%
pork_word_df = word_counts(pork_df)
pork_word_df.head(10)
# Out:
#           Word  Count
# 0         pork     61
# 19    sausages     14
# 1            &      9
# 49  lethbridge      6
# 32     italian      6
# 50        loin      6
# 13        free      5
# 14        from      5
# 51      centre      4
# 34        buns      4

# %%
word_list = ['italian','garlic','hot','bbq','flavour']
pork_df = exclude_product_rows(pork_df, word_list)

# %%
word_list = ['free from lean ground pork', 'pork loin half boneless frozen', 'medium ground pork']
pork_df = include_product_rows(pork_df, word_list, 'pork')

# %%
final_df = combine_dataframes(final_df, pork_df)
final_df
# Out:
#                  brand                                       product_name  \
# 0              no name                                        eggs, large
# 1              no name                           grade a large brown eggs
# 2       burnbrae farms                         naturegg simply egg whites
# 3       burnbrae farms               naturegg nest laid white eggs, large
# 4        golden valley                           born 3 white eggs, large
# 5       burnbrae farms                 naturegg omega 3 white eggs, large
# 6        golden valley                            white eggs, extra large
# 7          pc organics                        free range large brown eggs
# 8          pc organics  free-range large brown eggs, club pack (30 count)
# 9         zabiha halal                                   chicken sausages
# 10               sufra                         extra lean ground chicken
# 11               sufra                                halal whole chicken
# 12             no name                  club pack chicken thighs, bone-in
# 13             no name              honey garlic chicken wings, club pack
# 14             no name                           chicken wings, club pack
# 15             no name                     club pack chicken wings, split
# 16             no name       club pack chicken breasts, boneless skinless
# 17  president's choice                         free from lean ground pork
# 18                 NaN                                 medium ground pork
# 19                 NaN                     pork loin half boneless frozen
#
#     base_price product_size price_per_unit  unit_price_value unit_measure  \
# 0         4.16        12 ea      $0.35/1ea              0.35          1ea
# 1         5.37        12 ea      $0.45/1ea              0.45          1ea
# 2         5.39         1 ea    $1.08/100ml              1.08        100ml
# 3         5.69        12 ea      $0.47/1ea              0.47          1ea
# 4         5.99        12 ea      $0.50/1ea              0.50          1ea
# 5         6.49        12 ea      $0.54/1ea              0.54          1ea
# 6         7.07        18 ea      $0.39/1ea              0.39          1ea
# 7         7.99        12 ea      $0.67/1ea              0.67          1ea
# 8        16.99        30 ea      $0.57/1ea              0.57          1ea
# 9         6.99        375 g     $1.86/100g              1.86         100g
# 10        8.00        454 g     $1.76/100g              1.76         100g
# 11       14.00       1.7 kg     $0.82/100g              0.82         100g
# 12       17.99         2 kg     $0.90/100g              0.90         100g
# 13       26.50      1.81 kg     $1.46/100g              1.46         100g
# 14       26.50      1.81 kg     $1.46/100g              1.46         100g
# 15       26.99         2 kg     $1.35/100g              1.35         100g
# 16       39.99         2 kg     $2.00/100g              2.00         100g
# 17        5.49        454 g     $1.21/100g              1.21         100g
# 18       11.00        750 g     $1.47/100g              1.47         100g
# 19       15.57    $6.61/1kg      $3.00/1lb              3.00          1lb
#
#        item
# 0      eggs
# 1      eggs
# 2      eggs
# 3      eggs
# 4      eggs
# 5      eggs
# 6      eggs
# 7      eggs
# 8      eggs
# 9   chicken
# 10  chicken
# 11  chicken
# 12  chicken
# 13  chicken
# 14  chicken
# 15  chicken
# 16  chicken
# 17     pork
# 18     pork
# 19     pork

# %% [markdown]
# #### 4. Beef

# %%
word = 'beef'
beef_df  = food_item(word)
beef_df
# Out:
#                    brand                                       product_name  \
# 8290             sapporo               ichiban japanese style noodles, beef
# 8542           nong shim                         cup noodle, oolongmen beef
# 6058             no name                                         beef broth
# 7020           lucky me!                           instant noodle soup beef
# 3292         carl buddig                                        corned beef
# ...                  ...                                                ...
# 2778                 NaN                      beef rib finger meat boneless
# 2930                 NaN                         beef tenderloin, club pack
# 2781                 NaN                beef outside round roast, club pack
# 9617  president's choice   certified angus beef strip loin steak, club pack
# 431                  NaN  certified angus beef rib cap off grilling stea...
#
#       base_price product_size          price_per_unit  unit_price_value  \
# 8290        0.77        100 g              $1.19/100g              1.19
# 8542        1.29         75 g              $1.72/100g              1.72
# 6058        1.79       900 ml             $0.20/100ml              0.20
# 7020        1.89         70 g              $2.70/100g              2.70
# 3292        1.99         55 g   $36.18/1kg $3.62/100g             36.18
# ...          ...          ...                     ...               ...
# 2778       38.48   $26.43/1kg              $11.99/1lb             11.99
# 2930       47.45   $79.34/1kg              $36.00/1lb             36.00
# 2781       48.05   $26.43/1kg              $11.99/1lb             11.99
# 9617       48.75   $55.09/1kg              $25.00/1lb             25.00
# 431        56.15   $57.30/1kg              $26.00/1lb             26.00
#
#      unit_measure
# 8290         100g
# 8542         100g
# 6058        100ml
# 7020         100g
# 3292          1kg
# ...           ...
# 2778          1lb
# 2930          1lb
# 2781          1lb
# 9617          1lb
# 431           1lb
#
# [116 rows x 7 columns]

# %% [markdown]
# Taking food items having beef in `product_name` with `base_price` more than 7 as below it would consist of unuseful items

# %%
beef_df = beef_df[beef_df['base_price'] >= 7]
beef_df = beef_df.sort_values(by = 'base_price')

# %%
word_list = ['grass-fed medium ground beef', 'grass fed lean ground beef', 'free from lean ground beef', 'extra lean ground beef, club pack', 'beef tenderloin, club pack']
beef_df = include_product_rows(beef_df, word_list, 'beef')

# %%
from typing_extensions import final
final_df = combine_dataframes(final_df, beef_df)
final_df
# Out:
#                  brand                                       product_name  \
# 0              no name                                        eggs, large
# 1              no name                           grade a large brown eggs
# 2       burnbrae farms                         naturegg simply egg whites
# 3       burnbrae farms               naturegg nest laid white eggs, large
# 4        golden valley                           born 3 white eggs, large
# 5       burnbrae farms                 naturegg omega 3 white eggs, large
# 6        golden valley                            white eggs, extra large
# 7          pc organics                        free range large brown eggs
# 8          pc organics  free-range large brown eggs, club pack (30 count)
# 9         zabiha halal                                   chicken sausages
# 10               sufra                         extra lean ground chicken
# 11               sufra                                halal whole chicken
# 12             no name                  club pack chicken thighs, bone-in
# 13             no name              honey garlic chicken wings, club pack
# 14             no name                           chicken wings, club pack
# 15             no name                     club pack chicken wings, split
# 16             no name       club pack chicken breasts, boneless skinless
# 17  president's choice                         free from lean ground pork
# 18                 NaN                                 medium ground pork
# 19                 NaN                     pork loin half boneless frozen
# 20                 NaN                       grass-fed medium ground beef
# 21                 NaN                         grass fed lean ground beef
# 22  president's choice                         free from lean ground beef
# 23                 NaN                 grass fed lean ground beef, 2-pack
# 24                 NaN                  extra lean ground beef, club pack
# 25                 NaN                         beef tenderloin, club pack
#
#     base_price product_size price_per_unit  unit_price_value unit_measure  \
# 0         4.16        12 ea      $0.35/1ea              0.35          1ea
# 1         5.37        12 ea      $0.45/1ea              0.45          1ea
# 2         5.39         1 ea    $1.08/100ml              1.08        100ml
# 3         5.69        12 ea      $0.47/1ea              0.47          1ea
# 4         5.99        12 ea      $0.50/1ea              0.50          1ea
# 5         6.49        12 ea      $0.54/1ea              0.54          1ea
# 6         7.07        18 ea      $0.39/1ea              0.39          1ea
# 7         7.99        12 ea      $0.67/1ea              0.67          1ea
# 8        16.99        30 ea      $0.57/1ea              0.57          1ea
# 9         6.99        375 g     $1.86/100g              1.86         100g
# 10        8.00        454 g     $1.76/100g              1.76         100g
# 11       14.00       1.7 kg     $0.82/100g              0.82         100g
# 12       17.99         2 kg     $0.90/100g              0.90         100g
# 13       26.50      1.81 kg     $1.46/100g              1.46         100g
# 14       26.50      1.81 kg     $1.46/100g              1.46         100g
# 15       26.99         2 kg     $1.35/100g              1.35         100g
# 16       39.99         2 kg     $2.00/100g              2.00         100g
# 17        5.49        454 g     $1.21/100g              1.21         100g
# 18       11.00        750 g     $1.47/100g              1.47         100g
# 19       15.57    $6.61/1kg      $3.00/1lb              3.00          1lb
# 20        7.50        450 g     $1.67/100g              1.67         100g
# 21        8.00        450 g     $1.78/100g              1.78         100g
# 22        9.00        454 g     $1.98/100g              1.98         100g
# 23       15.00        900 g     $1.67/100g              1.67         100g
# 24       22.96   $17.61/1kg      $7.99/1lb              7.99          1lb
# 25       47.45   $79.34/1kg     $36.00/1lb             36.00          1lb
#
#        item
# 0      eggs
# 1      eggs
# 2      eggs
# 3      eggs
# 4      eggs
# 5      eggs
# 6      eggs
# 7      eggs
# 8      eggs
# 9   chicken
# 10  chicken
# 11  chicken
# 12  chicken
# 13  chicken
# 14  chicken
# 15  chicken
# 16  chicken
# 17     pork
# 18     pork
# 19     pork
# 20     beef
# 21     beef
# 22     beef
# 23     beef
# 24     beef
# 25     beef

# %% [markdown]
# #### 5. Peanuts

# %%
word = 'peanuts'
peanuts_df  = food_item(word)
peanuts_df
# Out:
#                    brand                                      product_name  \
# 1821                 t&t                              chili coated peanuts
# 3762                 t&t                     wasabi flavour coated peanuts
# 744              jabsons                         roasted peanuts bar-b-que
# 153              jabsons                 roasted peanuts classic salted
# 3720          reddi bulk                                   praline peanuts
# 7646          reddi bulk                             honey roasted peanuts
# 3012                kind   peanuts salted caramel nut & dark chocolate bar
# 4074          guru lucky                                     chili peanuts
# 8771             no name                           salted blanched peanuts
# 9746  president's choice                           salted virginia peanuts
# 6199                 t&t                                   roasted peanuts
# 2815             no name                      seasoned dry roasted peanuts
# 9258            planters                               maple syrup peanuts
# 6196        pc blue menu                 just peanuts smooth peanut butter
# 9445        pc blue menu                just peanuts crunchy peanut butter
# 5902  president's choice                             honey roasted peanuts
# 1488  president's choice                                  unsalted peanuts
# 8800  president's choice            peanuts dry roasted & lightly seasoned
# 9502            planters           dry roasted peanuts delicately seasoned
# 276   president's choice                    milk chocolate covered peanuts
# 574          pc organics                     dry-roasted peanuts, unsalted
# 858          pc organics                       dry-roasted peanuts, salted
# 5503             no name                 salted blanched peanuts club size
# 7095  president's choice                    milk chocolate covered peanuts
# 9991                kind  peanuts salted caramel nut & dark chocolate bars
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 1821        1.79        140 g     $1.28/100g              1.28         100g
# 3762        1.79        140 g     $1.28/100g              1.28         100g
# 744         1.99        140 g     $1.42/100g              1.42         100g
# 153         1.99        160 g     $1.24/100g              1.24         100g
# 3720        2.00        150 g     $1.33/100g              1.33         100g
# 7646        2.00        150 g     $1.33/100g              1.33         100g
# 3012        2.49         40 g     $6.23/100g              6.23         100g
# 4074        3.29        341 g     $0.96/100g              0.96         100g
# 8771        4.49        500 g     $0.90/100g              0.90         100g
# 9746        5.00        454 g     $1.10/100g              1.10         100g
# 6199        5.49        500 g     $1.10/100g              1.10         100g
# 2815        5.49        650 g     $0.84/100g              0.84         100g
# 9258        5.49        200 g     $2.75/100g              2.75         100g
# 6196        5.50        750 g     $0.87/100g              0.87         100g
# 9445        5.50        750 g     $0.87/100g              0.87         100g
# 5902        6.49        700 g     $0.93/100g              0.93         100g
# 1488        6.49        700 g     $0.93/100g              0.93         100g
# 8800        6.49        700 g     $0.93/100g              0.93         100g
# 9502        6.49        300 g     $2.16/100g              2.16         100g
# 276         8.00        400 g     $2.00/100g              2.00         100g
# 574        11.50        700 g     $1.64/100g              1.64         100g
# 858        11.50        700 g     $1.64/100g              1.64         100g
# 5503       13.49         2 kg     $0.67/100g              0.67         100g
# 7095       14.99        908 g     $1.65/100g              1.65         100g
# 9991       15.99    12x40.0 g     $4.58/100g              4.58         100g

# %%
word_list = ['unsalted peanuts']
peanuts_df = include_product_rows(peanuts_df, word_list, 'peanuts')

# %%
final_df = combine_dataframes(final_df, peanuts_df)

# %% [markdown]
# #### 6. Almonds

# %%
word = 'almonds'
almonds_df  = food_item(word)
almonds_df
# Out:
#                    brand                                       product_name  \
# 5541             no name                                  slivered almonds
# 3239             liberte  greek 2% vanilla bean yogurt crunch cups with ...
# 2186                post                                with almonds cereal
# 198   president's choice                        milk chocolate with almonds
# 4857            kelloggs  special k nourish dark chocolate chunks & almo...
# 6076            kelloggs        special k nourish cranberries & almonds bar
# 8240               amira                                    natural almonds
# 5911  president's choice                      roasted almonds with sea salt
# 9220  president's choice              hickory smoke flavour roasted almonds
# 2498        blue diamond                                almonds, smokehouse
# 3660  president's choice                             raw california almonds
# 3490  president's choice          salted cashews almonds and macadamia nuts
# 3721               prana                 organic nirvana sea salted almonds
# 1165  president's choice                        olives stuffed with almonds
# 7308               prana                     organic amandine maple almonds
# 7307                elan                                organic raw almonds
# 8018  president's choice                     milk chocolate covered almonds
# 9064  president's choice            unsalted dry roasted california almonds
# 9701        pc blue menu                 just almonds crunchy almond butter
# 6036  president's choice       dry roasted california almonds with sea salt
# 4553  president's choice                    dark chocolate bar with almonds
# 566         pc blue menu                                   unsalted almonds
# 4044         pc organics                                     sliced almonds
# 529    organically yours                                       almonds, raw
# 5956     farmer's market                             salted roasted almonds
# 9561     farmer's market                           unsalted roasted almonds
# 585    organically yours           organic almonds, roasted & unsalted test
# 8318        blue diamond                            almonds, lightly salted
# 9153        blue diamond                               almonds, smokehouse
# 8690        blue diamond                            roasted almonds, salted
# 126         blue diamond                                       almonds, bbq
# 5815          royal nuts                       dry roasted sea salt almonds
# 5148          royal nuts                                dry roasted almonds
# 977   president's choice                     dark chocolate covered almonds
# 811   president's choice  almonds, bananas, pineapple, cranberries & wal...
# 1609  president's choice      raisins almonds cashews cranberries trail mix
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 5541        2.79        100 g     $2.79/100g              2.79         100g
# 3239        3.00    2x130.0 g     $1.84/100g              1.84         100g
# 2186        3.33        340 g     $1.56/100g              1.56         100g
# 198         3.49        100 g     $3.49/100g              3.49         100g
# 4857        3.79        165 g     $2.60/100g              2.60         100g
# 6076        3.79        165 g     $2.60/100g              2.60         100g
# 8240        5.00        200 g     $2.50/100g              2.50         100g
# 5911        5.29        200 g     $2.65/100g              2.65         100g
# 9220        5.29        200 g     $2.65/100g              2.65         100g
# 2498        5.99        170 g     $3.52/100g              3.52         100g
# 3660        7.00        400 g     $1.75/100g              1.75         100g
# 3490        7.00        200 g     $3.50/100g              3.50         100g
# 3721        7.49        150 g     $4.99/100g              4.99         100g
# 1165        7.49       375 ml    $2.00/100ml              2.00        100ml
# 7308        7.49        150 g     $4.99/100g              4.99         100g
# 7307        7.79        200 g     $3.90/100g              3.90         100g
# 8018        8.00        340 g     $2.35/100g              2.35         100g
# 9064        8.00        375 g     $2.13/100g              2.13         100g
# 9701        8.00        340 g     $2.35/100g              2.35         100g
# 6036        8.00        375 g     $2.13/100g              2.13         100g
# 4553        8.49        300 g     $2.83/100g              2.83         100g
# 566         8.49        275 g     $3.09/100g              3.09         100g
# 4044        9.50        200 g     $4.75/100g              4.75         100g
# 529        10.00        200 g     $5.00/100g              5.00         100g
# 5956       10.00        350 g     $2.86/100g              2.86         100g
# 9561       10.00        350 g     $2.86/100g              2.86         100g
# 585        12.00        200 g     $6.00/100g              6.00         100g
# 8318       13.99    18x23.0 g     $3.38/100g              3.38         100g
# 9153       13.99    18x23.0 g     $3.38/100g              3.38         100g
# 8690       13.99        454 g     $3.08/100g              3.08         100g
# 126        13.99        454 g     $3.08/100g              3.08         100g
# 5815       14.00        325 g     $4.31/100g              4.31         100g
# 5148       14.00        325 g     $4.31/100g              4.31         100g
# 977        14.99        700 g     $2.14/100g              2.14         100g
# 811        15.99        700 g     $2.28/100g              2.28         100g
# 1609       15.99        700 g     $2.28/100g              2.28         100g

# %%
word_list = ['natural almonds', 'raw california almonds']
almonds_df = include_product_rows(almonds_df, word_list, 'almonds')
final_df = combine_dataframes(final_df, almonds_df)

# %% [markdown]
# #### 7. Cashews

# %%
word = 'cashews'
cashew_df  = food_item(word)
cashew_df
# Out:
#                    brand                                   product_name  \
# 2959                 NaN                         roasted salted cashews
# 9591  president's choice                       unsalted roasted cashews
# 9225  president's choice                 roasted cashews with sea salt
# 1362            planters                        cashews ranch flavoured
# 3953                elan                            organic raw cashews
# 8475            planters               cashews salt & vinegar flavoured
# 2690            planters                      cashews, roasted & salted
# 5934         pc organics                        whole raw cashews 200 g
# 3490  president's choice      salted cashews almonds and macadamia nuts
# 954                 elan                        coconut cashews organic
# 190   president's choice                         milk chocolate cashews
# 5659     farmer's market                     salted dry-roasted cashews
# 4033           dan d pak                               cashews sea salt
# 5656          royal nuts                  dry roasted cashews, unsalted
# 1440           dan d pak                                cashews, salted
# 1609  president's choice  raisins almonds cashews cranberries trail mix
# 2444  president's choice              dry roasted cashews with sea salt
# 5219  president's choice                                    raw cashews
# 5949  president's choice                  roasted cashews with sea salt
# 686          pc organics                      whole raw cashews, 1.13kg
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 2959        3.00   $3.00/100g     $13.61/1lb             13.61          1lb
# 9591        5.79        200 g     $2.90/100g              2.90         100g
# 9225        5.79        200 g     $2.90/100g              2.90         100g
# 1362        6.49        145 g     $4.48/100g              4.48         100g
# 3953        6.49        185 g     $3.51/100g              3.51         100g
# 8475        6.49        145 g     $4.48/100g              4.48         100g
# 2690        6.49        200 g     $3.25/100g              3.25         100g
# 5934        6.50        200 g     $3.25/100g              3.25         100g
# 3490        7.00        200 g     $3.50/100g              3.50         100g
# 954         7.99        160 g     $4.99/100g              4.99         100g
# 190         8.00        250 g     $3.20/100g              3.20         100g
# 5659       10.00        350 g     $2.86/100g              2.86         100g
# 4033       10.99        500 g     $2.20/100g              2.20         100g
# 5656       14.00        350 g     $4.00/100g              4.00         100g
# 1440       15.49        908 g     $1.76/100g              1.76         100g
# 1609       15.99        700 g     $2.28/100g              2.28         100g
# 2444       16.00        680 g     $2.35/100g              2.35         100g
# 5219       16.00        680 g     $2.35/100g              2.35         100g
# 5949       22.99      1.13 kg     $2.03/100g              2.03         100g
# 686        27.00      1.13 kg     $2.39/100g              2.39         100g

# %%
word_list = ['unsalted roasted cashews', 'raw cashews', 'whole raw cashews']

cashew_df = include_product_rows(cashew_df, word_list, 'cashew')
final_df = combine_dataframes(final_df, cashew_df)

# %% [markdown]
# #### 8. Sunflower Seeds

# %%
word = 'sunflower seeds'
sunflower_df  = food_item(word)
sunflower_df
# Out:
#                    brand                         product_name  base_price  \
# 3484          reddi bulk               salted sunflower seeds        2.00
# 5199          reddi bulk     salted sunflower seeds, in shell        2.00
# 7219             cha cha      sunflower seeds coconut flavour        2.99
# 231          pc organics   dry-roasted salted sunflower seeds        2.99
# 8645               spitz  dill pickle flavour sunflower seeds        3.49
# 7374     farmer's market       salted roasted sunflower seeds        5.00
# 7671     farmer's market     unsalted roasted sunflower seeds        5.00
# 473   president's choice                  raw sunflower seeds        5.00
# 5193    stock and barrel       sunflower seeds roasted salted        7.00
#
#      product_size price_per_unit  unit_price_value unit_measure
# 3484        165 g     $1.21/100g              1.21         100g
# 5199        150 g     $1.33/100g              1.33         100g
# 7219        260 g     $1.15/100g              1.15         100g
# 231         200 g     $1.50/100g              1.50         100g
# 8645        210 g     $1.66/100g              1.66         100g
# 7374        400 g     $1.25/100g              1.25         100g
# 7671        400 g     $1.25/100g              1.25         100g
# 473         350 g     $1.43/100g              1.43         100g
# 5193        800 g     $0.88/100g              0.88         100g

# %%
word_list = ['unsalted roasted sunflower seeds', 'raw sunflower seeds']
sunflower_df = include_product_rows(sunflower_df, word_list, 'sunflower seeds')
final_df = combine_dataframes(final_df, sunflower_df)

# %% [markdown]
# #### 9. Perch

# %%
word = 'perch'
perch_df  = food_item(word)
perch_df
# Out:
#     brand product_name  base_price product_size price_per_unit  \
# 373   NaN  ocean perch       12.29    $8.80/1kg      $3.99/1lb
#
#      unit_price_value unit_measure
# 373              3.99          1lb

# %%
word_list = ['ocean perch']
perch_df = include_product_rows(perch_df, word_list, 'perch')
final_df = combine_dataframes(final_df, perch_df)

# %% [markdown]
# #### 10. Salmon

# %%
word = 'salmon'
salmon_df = food_item(word)
salmon_df
# Out:
#                    brand                                       product_name  \
# 8578         clover leaf                           pink salmon wild pacific
# 5690           raincoast                    wild pink salmon, no added salt
# 8051            goldseal                        wild pacific pink salmon
# 8132             no name       sustainably sourced wild pacific pink salmon
# 3463  president's choice     wild pacific pink salmon, sustainably sourced
# 2083         clover leaf                    sockeye salmon wild red pacific
# 998             goldseal                            wild salmon bowl fiesta
# 5825         clover leaf                           pink salmon wild pacific
# 9368             no name    sustainably sourced wild pacific sockeye salmon
# 7074            goldseal                                        pink salmon
# 1602            goldseal                                     salmon sockeye
# 7518                 NaN                            whole fresh pink salmon
# 663            blue tide                             salmon sashimi, frozen
# 8062                 NaN                     whole wild pink salmon, frozen
# 6065  president's choice                      candied salmon, maple flavour
# 2926                 NaN               farmed atlantic salmon fillet, fresh
# 4197           one ocean                   wild smoked pink salmon boneless
# 6578  president's choice                                      salmon tataki
# 7212         clover leaf                    wild salmon red pacific, 3 pack
# 2916               bento                                 salmon sushi combo
# 2899                 NaN      wild sockeye salmon fillet, previously frozen
# 7844              foppen                           smoked salmon toast trio
# 4328        pc blue menu  wild sockeye salmon sustainably sourced, skin-...
# 4210                 NaN            pacific wild coho salmon, whole dressed
# 9735                 NaN                    club size fresh atlantic salmon
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 8578        2.49        142 g     $2.67/100g              2.67         100g
# 5690        3.99        160 g     $2.49/100g              2.49         100g
# 8051        3.99        213 g     $2.11/100g              2.11         100g
# 8132        3.99        213 g     $1.87/100g              1.87         100g
# 3463        4.29        170 g     $2.52/100g              2.52         100g
# 2083        4.99        142 g     $3.51/100g              3.51         100g
# 998         4.99        160 g     $3.12/100g              3.12         100g
# 5825        5.29        213 g     $2.48/100g              2.48         100g
# 9368        5.49        213 g     $2.58/100g              2.58         100g
# 7074        5.99        418 g     $1.55/100g              1.55         100g
# 1602        5.99        213 g     $3.05/100g              3.05         100g
# 7518        7.92    $9.90/1kg      $4.49/1lb              4.49          1lb
# 663         7.99        100 g     $7.99/100g              7.99         100g
# 8062        8.90    $8.82/1kg      $4.00/1lb              4.00          1lb
# 6065       10.99        150 g     $7.33/100g              7.33         100g
# 2926       11.22   $39.66/1kg     $17.99/1lb             17.99          1lb
# 4197       12.99        454 g     $2.86/100g              2.86         100g
# 6578       13.00        130 g    $10.00/100g             10.00         100g
# 7212       13.99        142 g     $3.28/100g              3.28         100g
# 2916       16.00        377 g     $4.24/100g              4.24         100g
# 2899       16.51   $35.27/1kg     $16.00/1lb             16.00          1lb
# 7844       17.99        248 g     $7.25/100g              7.25         100g
# 4328       21.99        280 g     $7.85/100g              7.85         100g
# 4210       24.07   $17.61/1kg      $7.99/1lb              7.99          1lb
# 9735       30.30   $35.27/1kg     $16.00/1lb             16.00          1lb

# %%
word_list = ['wild pacific pink salmon', 'wild smoked pink salmon boneless']
salmon_df = include_product_rows(salmon_df, word_list, 'salmon')
final_df = combine_dataframes(final_df, salmon_df)

# %% [markdown]
# #### 11. Milk

# %%
word = 'milk'
milk_df = food_item(word)
milk_df
# Out:
#                    brand                                       product_name  \
# 3344               grace                             coconut milk, powdered
# 991              neilson                            crispy crunch milkshake
# 1412             neilson                           french vanilla milkshake
# 1388           maltesers               milk chocolate candy bar, single bag
# 7284             neilson                              jersey milk chocolate
# ...                  ...                                                ...
# 4198              bio k+                     kidz strawberry fermented milk
# 5941              bio k+          bio-k+ fermented milk probiotic, original
# 7405        nature's way                milk thistle 60 vegetarian capsules
# 465   president's choice  club pack fully cooked buttermilk chicken brea...
# 761               bio k+                        plus vanilla fermented milk
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 3344        0.99         50 g     $1.98/100g              1.98         100g
# 991         1.25       310 ml    $0.51/100ml              0.51        100ml
# 1412        1.25       310 ml    $0.51/100ml              0.51        100ml
# 1388        1.25         37 g     $3.38/100g              3.38         100g
# 7284        1.25         45 g     $2.78/100g              2.78         100g
# ...          ...          ...            ...               ...          ...
# 4198       21.49        588 g     $3.65/100g              3.65         100g
# 5941       26.99     6x98.0 g     $4.59/100g              4.59         100g
# 7405       35.49        60 ea      $0.59/1ea              0.59          1ea
# 465        35.99      1.81 kg     $1.99/100g              1.99         100g
# 761        46.99       1176 g     $4.00/100g              4.00         100g
#
# [167 rows x 7 columns]

# %%
milk_word_df = word_counts(milk_df)
milk_word_df.head(10)
# Out:
#           Word  Count
# 8         milk    143
# 9    chocolate     57
# 0      coconut     22
# 35          1%     14
# 19          2%     13
# 45        free     11
# 22        with     11
# 86  buttermilk     10
# 7      vanilla     10
# 85           &     10

# %%
word_list = ['chocolate','milkshake','flavour', 'coconut', 'buttermilk', 'coffee', 'vanilla', 'cheese', 'tea', 'flavor', 'cookies', 'ice']
milk_df = exclude_product_rows(milk_df, word_list)

# %%
word_list = ['almond milk alternative, zero sugar', 'oat milk alternative, unsweetened', 'plain goat milk yogurt']
milk_df = include_product_rows(milk_df, word_list, 'milk')
final_df = combine_dataframes(final_df, milk_df)

# %%
milk_df = df[df['brand'].str.contains('dairy', case=False, na=False)]
milk_df
# Out:
#           brand                     product_name  base_price product_size  \
# 16    dairyland                  2% regular milk        5.63          4 l
# 28    dairyland                       3.25% milk        5.98          4 l
# 549   dairyland                  2% organic milk        8.99          4 l
# 1003  dairyland                  0% regular milk        5.62          4 l
# 1036  dairyland                  2% regular milk        2.21       473 ml
# 1062  dairyland                  1% regular milk        5.63          4 l
# 1084  dairyland                  2% regular milk        2.87          1 l
# 1098  dairyland      3.25% protein 18 g beverage        6.99       1.89 l
# 1199  dairyland                1% chocolate milk        6.80          4 l
# 4432  dairyland  1% chocolate milk reduced sugar        4.32       1.89 l
# 4451  dairyland               33% whipping cream        3.21       237 ml
# 4460  dairyland               33% whipping cream        6.32       946 ml
# 4532  dairyland                 10% creamo cream        3.17       473 ml
# 4603  dairyland                  1% regular milk        2.88          1 l
# 4666  dairyland                  2% regular milk        4.85          2 l
# 4686  dairyland                    1% buttermilk        3.61       946 ml
# 4732  dairyland                   14% sour cream        5.99       750 ml
# 7363  dairyland                  1% organic milk        8.99          4 l
# 7505  dairyland                  2% regular milk        1.50       237 ml
# 7793  dairyland                 18% coffee cream        5.52       946 ml
# 7978  dairyland                4% cottage cheese        4.29        500 g
# 8079  dairyland                       3.25% milk        4.92          2 l
# 8094  dairyland                  1% regular milk        4.85          2 l
# 8130  dairyland                   14% sour cream        3.99       500 ml
# 9569  dairyland                  2% organic milk        6.69       1.89 l
#
#      price_per_unit  unit_price_value unit_measure
# 16      $0.14/100ml              0.14        100ml
# 28      $0.15/100ml              0.15        100ml
# 549     $0.25/100ml              0.25        100ml
# 1003    $0.14/100ml              0.14        100ml
# 1036    $0.47/100ml              0.47        100ml
# 1062    $0.14/100ml              0.14        100ml
# 1084    $0.29/100ml              0.29        100ml
# 1098    $0.37/100ml              0.37        100ml
# 1199    $0.17/100ml              0.17        100ml
# 4432    $0.23/100ml              0.23        100ml
# 4451    $1.35/100ml              1.35        100ml
# 4460    $0.67/100ml              0.67        100ml
# 4532    $0.67/100ml              0.67        100ml
# 4603    $0.29/100ml              0.29        100ml
# 4666    $0.24/100ml              0.24        100ml
# 4686    $0.38/100ml              0.38        100ml
# 4732    $0.80/100ml              0.80        100ml
# 7363    $0.25/100ml              0.25        100ml
# 7505    $0.63/100ml              0.63        100ml
# 7793    $0.58/100ml              0.58        100ml
# 7978     $0.94/100g              0.94         100g
# 8079    $0.25/100ml              0.25        100ml
# 8094    $0.24/100ml              0.24        100ml
# 8130    $0.90/100ml              0.90        100ml
# 9569    $0.35/100ml              0.35        100ml

# %%
milk_df = milk_df[(milk_df['base_price'] == 5.63) | (milk_df['base_price'] == 5.98) | (milk_df['base_price'] == 5.62)]
milk_df = milk_df.copy()
milk_df['item'] = 'milk'
milk_df
# Out:
#           brand     product_name  base_price product_size price_per_unit  \
# 16    dairyland  2% regular milk        5.63          4 l    $0.14/100ml
# 28    dairyland       3.25% milk        5.98          4 l    $0.15/100ml
# 1003  dairyland  0% regular milk        5.62          4 l    $0.14/100ml
# 1062  dairyland  1% regular milk        5.63          4 l    $0.14/100ml
#
#       unit_price_value unit_measure  item
# 16                0.14        100ml  milk
# 28                0.15        100ml  milk
# 1003              0.14        100ml  milk
# 1062              0.14        100ml  milk

# %%
final_df = combine_dataframes(final_df, milk_df)

# %% [markdown]
# #### 12. Yogurt

# %%
word = 'yogurt'
yogurt_df = food_item(word)
yogurt_df
# Out:
#         brand                                       product_name  base_price  \
# 1100  yoplait  yop 1% drinkable yogurt, fruity, yogurt drink ...        1.29
# 1092  yoplait   yop 1% drinkable yogurt, blueberry, yogurt drink        1.29
# 7983  yoplait   yop 1% drinkable yogurt, raspberry, yogurt drink        1.29
# 4581  yoplait  yop 1% drinkable yogurt, birthday cake limited...        1.29
# 7868  yoplait  yop 1% drinkable yogurt, mango, lactose free y...        1.29
# ...       ...                                                ...         ...
# 1227    oikos         greek yogurt, plain, no added sugar, 2% mf       11.99
# 749   liberte  greek 0% yogurt 16-pack, assorted, high protei...       12.49
# 2108  olympic                                no fat yogurt-plain       13.49
# 6500  olympic                  organic yogurt vanilla 3%, 1.75kg       13.49
# 2416  olympic                          organic plain yogurt 3.5%       13.49
#
#      product_size price_per_unit  unit_price_value unit_measure
# 1100       200 ml    $0.65/100ml              0.65        100ml
# 1092       200 ml    $0.65/100ml              0.65        100ml
# 7983       200 ml    $0.65/100ml              0.65        100ml
# 4581       200 ml    $0.65/100ml              0.65        100ml
# 7868       200 ml    $0.65/100ml              0.65        100ml
# ...           ...            ...               ...          ...
# 1227       1.5 kg     $0.80/100g              0.80         100g
# 749        1.6 kg     $0.78/100g              0.78         100g
# 2108      1.75 kg     $0.77/100g              0.77         100g
# 6500      1.75 kg     $0.77/100g              0.77         100g
# 2416      1.75 kg     $0.77/100g              0.77         100g
#
# [142 rows x 7 columns]

# %%
word_list = ['yogurt with probiotics lactose free', 'lactose free greek yogurt, plain', 'organic yogurt vanilla']
yogurt_df = include_product_rows(yogurt_df, word_list, 'yogurt')
final_df = combine_dataframes(final_df, yogurt_df)

# %%
word_list = ['fat free greek yogurt, high protein']
yogurt_df = include_product_rows(df, word_list, 'yogurt')
final_df = combine_dataframes(final_df, yogurt_df)

# %% [markdown]
# #### 13. Lentil

# %%
word = 'lentil'
lentil_df = food_item(word)
lentil_df
# Out:
#                        brand                                     product_name  \
# 5750                   unico                                          lentils
# 1045                    clic                                    brown lentils
# 7478                    clic                              eston green lentils
# 8047                    clic                              laird green lentils
# 988             pc blue menu           curried red lentil ready-to-serve soup
# 5383            pc blue menu  lentils and quinoa blend whole grain brown rice
# 1753            pc blue menu                                    green lentils
# 7675       kitchens of india                          black gram lentil curry
# 5197             pc organics                              organic red lentils
# 1446             pc organics                            organic green lentils
# 4863                  pataks                 lentil tikka masala ready to eat
# 3713           floating leaf        wild rice & quinoa, whole grain & lentils
# 6440           three farmers                  crunchy little lentils barbecue
# 3670           three farmers              crunchy lentil topper bacon flavour
# 7809                   suraj                                red split lentils
# 6709                 quality                                       red lentil
# 6059             pc organics                    organic red lentil rice penne
# 3942  old dutch project nice     red lentil veggie snacks sweet onion flavour
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 5750        1.99       540 ml    $0.37/100ml              0.37        100ml
# 1045        2.99        907 g     $0.33/100g              0.33         100g
# 7478        2.99        907 g     $0.33/100g              0.33         100g
# 8047        2.99        907 g     $0.33/100g              0.33         100g
# 988         3.00       500 ml    $0.60/100ml              0.60        100ml
# 5383        3.29        250 g     $1.32/100g              1.32         100g
# 1753        3.79        900 g     $0.42/100g              0.42         100g
# 7675        3.79       270 ml    $1.40/100ml              1.40        100ml
# 5197        4.00        450 g     $0.89/100g              0.89         100g
# 1446        4.00        450 g     $0.89/100g              0.89         100g
# 4863        4.29       285 ml    $1.51/100ml              1.51        100ml
# 3713        4.99        400 g     $1.25/100g              1.25         100g
# 6440        4.99        140 g     $3.56/100g              3.56         100g
# 3670        5.29        140 g     $3.78/100g              3.78         100g
# 7809        5.29       1.8 kg     $0.29/100g              0.29         100g
# 6709        5.99      1.81 kg     $0.33/100g              0.33         100g
# 6059        6.00        227 g     $2.64/100g              2.64         100g
# 3942        6.49        150 g     $4.33/100g              4.33         100g

# %%
word_list = ['red split lentils', 'green lentils']
lentil_df = lentil_df[(lentil_df['base_price'] == 3.79) | (lentil_df['base_price'] == 5.29)]
lentil_df = include_product_rows(lentil_df, word_list, 'lentil')
final_df = combine_dataframes(final_df, lentil_df)

# %% [markdown]
# #### 14. Chickpeas

# %%
word = 'chickpeas'
chickpeas_df = food_item(word)
chickpeas_df
# Out:
#               brand                       product_name  base_price  \
# 5159          suraj                          chickpeas        1.29
# 3686          tamam                 lebanese chickpeas        1.49
# 9394          suraj                          chickpeas        3.50
# 9141   pc blue menu                          chickpeas        3.79
# 5626         pataks      butter chickpeas ready to eat        4.29
# 4190  three farmers  roasted chickpeas sea salt & lime        4.99
# 8078          suraj                          chickpeas        5.49
# 581         quality                          chickpeas        6.99
#
#      product_size price_per_unit  unit_price_value unit_measure
# 5159       540 ml    $0.28/100ml              0.28        100ml
# 3686        400 g     $0.37/100g              0.37         100g
# 9394        907 g     $0.39/100g              0.39         100g
# 9141        900 g     $0.42/100g              0.42         100g
# 5626          285             ml               NaN          NaN
# 4190        120 g     $4.16/100g              4.16         100g
# 8078       1.8 kg     $0.31/100g              0.31         100g
# 581        1.8 kg     $0.39/100g              0.39         100g

# %%
word_list = ['chickpea']
chickpeas_df = chickpeas_df[(chickpeas_df['base_price'] == 5.49)]
chickpeas_df = include_product_rows(chickpeas_df, word_list, 'chickpeas')
final_df = combine_dataframes(final_df, chickpeas_df)

# %% [markdown]
# ####15. Beans

# %%
word = 'beans'
beans_df = food_item(word)
beans_df
# Out:
#             brand                                product_name  base_price  \
# 3398          NaN                                 green beans        1.10
# 327         tamam                                 pinto beans        1.29
# 1614        tamam                     faba beans foul medamas        1.29
# 8463        tamam                             small red beans        1.29
# 8611        tamam                          white kidney beans        1.29
# ...           ...                                         ...         ...
# 4066  jelly belly              jelly beans, assorted flavours        7.29
# 3925      quality                      red kidney beans, dark        7.99
# 7362      no name                 baked beans in tomato sauce       17.00
# 7093      quality                              blackeye beans       21.99
# 1738      lavazza  crema e gusto whole coffee beans, classico       28.99
#
#      product_size price_per_unit  unit_price_value unit_measure
# 3398   $1.10/100g     $11.00/1kg             11.00          1kg
# 327        540 ml    $0.28/100ml              0.28        100ml
# 1614       540 ml    $0.28/100ml              0.28        100ml
# 8463       540 ml    $0.28/100ml              0.28        100ml
# 8611       540 ml    $0.28/100ml              0.28        100ml
# ...           ...            ...               ...          ...
# 4066        255 g     $2.86/100g              2.86         100g
# 3925      1.81 kg     $0.44/100g              0.44         100g
# 7362  12x398.0 ml    $0.36/100ml              0.36        100ml
# 7093         5 kg     $0.44/100g              0.44         100g
# 1738         1 kg     $2.90/100g              2.90         100g
#
# [72 rows x 7 columns]

# %%
word_list = ['light red kidney beans', 'pinto beans']
beans_df = beans_df[(beans_df['base_price'] == 1.29) | (beans_df['base_price'] == 5.49)]
beans_df = include_product_rows(beans_df, word_list, 'beans')
final_df = combine_dataframes(final_df, beans_df)

# %% [markdown]
# #### 16. Tofu

# %%
word = 'tofu'
tofu_df = food_item(word)
tofu_df
# Out:
#                  brand                  product_name  base_price product_size  \
# 776            sunrise        tofu dessert, original        2.29    2x150.0 g
# 3470          soyganic             tofu soft organic        2.29        300 g
# 8413           sunrise    tofu dessert, peach mango         2.29    2x150.0 g
# 9233           sunrise             tofu, medium firm        2.47        454 g
# 3764           rooster                   silken tofu        2.49        454 g
# 4271           sunrise             premium soft tofu        2.79        530 g
# 30             sunrise              tofu, extra firm        3.49        350 g
# 9305          soyganic       tofu firm organic 500 g        3.79        500 g
# 206           soyganic      medium firm organic tofu        3.99        454 g
# 8243          kikkoman       instant miso soup, tofu        3.99         30 g
# 9210          soyganic       organic tofu extra firm        3.99        350 g
# 8581  superior natural      organic tofu medium firm        4.99        454 g
# 802       big mountain  the superfood fava tofu firm        6.99        340 g
#
#      price_per_unit  unit_price_value unit_measure
# 776      $0.76/100g              0.76         100g
# 3470     $0.76/100g              0.76         100g
# 8413     $0.76/100g              0.76         100g
# 9233     $0.54/100g              0.54         100g
# 3764     $0.55/100g              0.55         100g
# 4271     $0.53/100g              0.53         100g
# 30       $1.00/100g              1.00         100g
# 9305     $0.76/100g              0.76         100g
# 206      $0.88/100g              0.88         100g
# 8243    $13.30/100g             13.30         100g
# 9210     $1.14/100g              1.14         100g
# 8581     $1.10/100g              1.10         100g
# 802      $2.06/100g              2.06         100g

# %%
word_list = ['tofu']
tofu_df = tofu_df[(tofu_df['product_name'] == 'premium soft tofu') | (tofu_df['base_price'] == 2.47)]
tofu_df = include_product_rows(tofu_df, word_list, 'tofu')
final_df = combine_dataframes(final_df, tofu_df)

# %% [markdown]
# #### 17. Rice

# %%
word = 'rice'
rice_df = food_item(word)
rice_df
# Out:
#          brand                                       product_name  base_price  \
# 1807      bens              fast & fancy chinese style fried rice        0.97
# 2769      bens           fast & fancy garden vegetable style rice        0.97
# 9397      bens  fast & fancy homestyle chicken flavour & wild ...        0.97
# 7023     panda                          licorice strawberry candy        1.39
# 7238   quality                   puffed rice brittle mamra chikki        1.49
# ...        ...                                                ...         ...
# 8859    bio k+              bio-k+ organic rice, blueberry 6-pack       26.99
# 2675      rose                         jasmine white scented rice       29.99
# 2447  kohinoor                           organic sonamasoori rice       31.99
# 4070     heiwa                 calrose rice, premium sushi rice         39.99
# 3162   no name                        extra fancy long grain rice       42.49
#
#      product_size price_per_unit  unit_price_value unit_measure
# 1807        132 g     $1.43/100g              1.43         100g
# 2769        132 g     $1.43/100g              1.43         100g
# 9397        132 g     $1.43/100g              1.43         100g
# 7023         32 g     $4.34/100g              4.34         100g
# 7238        100 g     $1.49/100g              1.49         100g
# ...           ...            ...               ...          ...
# 8859     6x98.0 g     $4.59/100g              4.59         100g
# 2675         8 kg     $0.37/100g              0.37         100g
# 2447    9x9.08 kg     $0.35/100g              0.35         100g
# 4070      18.1 kg     $0.22/100g              0.22         100g
# 3162        18 kg     $0.24/100g              0.24         100g
#
# [185 rows x 7 columns]

# %%
word_list = ['premium basmati rice', 'extra fancy long grain white rice club size']
rice_df = include_product_rows(rice_df, word_list, 'rice')
final_df = combine_dataframes(final_df, rice_df)

# %% [markdown]
# #### 18. Quinoa

# %%
word = 'quinoa'
quinoa_df = food_item(word)
quinoa_df
# Out:
#               brand                                       product_name  \
# 5409   pc blue menu             whole grain blend with quinoa & barley
# 5383   pc blue menu    lentils and quinoa blend whole grain brown rice
# 5545          kashi  7 grain with quinoa crunchy bars, honey oat fl...
# 9227          kashi  crunchy 7 grain with quinoa bars apple cinnamo...
# 6738    clover leaf                 tuna salad with quinoa & olive oil
# 4631    gogo quinoa                      rice & quinoa spaghetti pasta
# 1253    gogo quinoa                       rice & quinoa macaroni pasta
# 187     gogo quinoa                pink salt and vinegar quinoa puffs
# 7531    gogo quinoa                  vegan white cheddar quinoa puffs
# 7026    gogo quinoa         gogo puffs quinoa puffs snacks dill pickle
# 883          casbah                  quinoa & brown rice herb & garlic
# 7261         casbah                            quinoa & ancient grains
# 7677         casbah                                quinoa, whole grain
# 8668    green giant  restaurant sides broccoli spinach florentine, ...
# 3713  floating leaf          wild rice & quinoa, whole grain & lentils
# 2463           clic                                  quinoa grains box
# 9565           clic                                  red quinoa grains
# 5995    pc organics                                quinoa rice fusilli
# 4864         tipiak                               quinoa gourmand
# 8004     one degree                      quinoa cacao granola sprouted
# 1809    gogo quinoa                     organic royal tri-color quinoa
# 3766    gogo quinoa                     organic royal tri-color quinoa
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 5409        3.29        250 g     $1.32/100g              1.32         100g
# 5383        3.29        250 g     $1.32/100g              1.32         100g
# 5545        3.79        200 g     $2.15/100g              2.15         100g
# 9227        3.79        200 g     $2.15/100g              2.15         100g
# 6738        3.99        160 g     $2.49/100g              2.49         100g
# 4631        3.99        227 g     $1.98/100g              1.98         100g
# 1253        3.99        227 g     $1.98/100g              1.98         100g
# 187         4.29        113 g     $3.80/100g              3.80         100g
# 7531        4.29        113 g     $3.80/100g              3.80         100g
# 7026        4.29        113 g     $3.80/100g              3.80         100g
# 883         4.49        180 g     $2.66/100g              2.66         100g
# 7261        4.49        180 g     $2.66/100g              2.66         100g
# 7677        4.49        200 g     $2.40/100g              2.40         100g
# 8668        4.49        283 g     $1.76/100g              1.76         100g
# 3713        4.99        400 g     $1.25/100g              1.25         100g
# 2463        5.99        500 g     $1.20/100g              1.20         100g
# 9565        5.99        500 g     $1.20/100g              1.20         100g
# 5995        6.00        227 g     $2.64/100g              2.64         100g
# 4864        6.99        350 g     $2.00/100g              2.00         100g
# 8004        7.49        312 g     $2.72/100g              2.72         100g
# 1809        8.49        500 g     $1.70/100g              1.70         100g
# 3766       21.99       1800 g     $1.22/100g              1.22         100g

# %%
word_list = ['organic royal tri-color quinoa']
quinoa_df = include_product_rows(quinoa_df, word_list, 'quinoa')
final_df = combine_dataframes(final_df, quinoa_df)

# %% [markdown]
# #### 19. Oats

# %%
word = 'oats'
oats_df = food_item(word)
oats_df
# Out:
#               brand                                       product_name  \
# 5041    peek freans  lifestyle selections cranberry citrus oats bis...
# 1600        leclerc  go pure fruit & oats bars, chocolate & strawberry
# 6095        no name                   one minute 100% whole grain oats
# 8344      dan d pak                                         quick oats
# 4923      dan d pak                                        rolled oats
# 1756         quaker                                    one minute oats
# 8400         quaker                                         quick oats
# 2437  nature valley     crunchy dipped granola squares chocolatey oats
# 8981     robin hood                       100% whole grains quick oats
# 1929     robin hood                      100% whole grains minute oats
# 5117    pc organics                             organic steel cut oats
# 1248  nature's path                                 organic cacao oats
# 8570  nature valley  protein granola, oats 'n honey, healthy snack ...
# 3934      britannia        oats chocolate & almond cookies family pack
# 5546  nature valley    crunchy oats 'n' honey granola bars family pack
# 3820  bobs red mill                  rolled oats old fashioned organic
# 690      one degree                               rolled oats sprouted
# 7687     one degree                                quick oats sprouted
# 4356    stoked oats                                     stone age oats
#
#       base_price product_size price_per_unit  unit_price_value unit_measure
# 5041        2.99        290 g     $1.55/100g              1.55         100g
# 1600        3.00        160 g     $2.68/100g              2.68         100g
# 6095        3.00        900 g     $0.33/100g              0.33         100g
# 8344        3.49       1000 g     $0.35/100g              0.35         100g
# 4923        3.49       1000 g     $0.35/100g              0.35         100g
# 1756        3.59        900 g     $0.44/100g              0.44         100g
# 8400        3.59         1 kg     $0.40/100g              0.40         100g
# 2437        3.99        132 g     $3.02/100g              3.02         100g
# 8981        4.29         1 kg     $0.43/100g              0.43         100g
# 1929        4.29         1 kg     $0.43/100g              0.43         100g
# 5117        4.99         1 kg     $0.50/100g              0.50         100g
# 1248        6.29        210 g     $3.00/100g              3.00         100g
# 8570        6.49        310 g     $2.09/100g              2.09         100g
# 3934        7.49        450 g     $1.66/100g              1.66         100g
# 5546        7.49        690 g     $1.09/100g              1.09         100g
# 3820        7.99        907 g     $0.94/100g              0.94         100g
# 690         7.99        680 g     $1.32/100g              1.32         100g
# 7687        7.99        680 g     $1.32/100g              1.32         100g
# 4356        9.99        500 g     $2.00/100g              2.00         100g

# %%
word_list = ['one minute 100% whole grain oats', 'quick oats']
oats_df = include_product_rows(oats_df, word_list, 'oats')
final_df = combine_dataframes(final_df, oats_df)

# %%
final_df
# Out:
#              brand                          product_name  base_price  \
# 0          no name                           eggs, large        4.16
# 1          no name              grade a large brown eggs        5.37
# 2   burnbrae farms            naturegg simply egg whites        5.39
# 3   burnbrae farms  naturegg nest laid white eggs, large        5.69
# 4    golden valley              born 3 white eggs, large        5.99
# ..             ...                                   ...         ...
# 63         no name      one minute 100% whole grain oats        3.00
# 64       dan d pak                            quick oats        3.49
# 65          quaker                            quick oats        3.59
# 66      robin hood          100% whole grains quick oats        4.29
# 67      one degree                   quick oats sprouted        7.99
#
#    product_size price_per_unit  unit_price_value unit_measure  item
# 0         12 ea      $0.35/1ea              0.35          1ea  eggs
# 1         12 ea      $0.45/1ea              0.45          1ea  eggs
# 2          1 ea    $1.08/100ml              1.08        100ml  eggs
# 3         12 ea      $0.47/1ea              0.47          1ea  eggs
# 4         12 ea      $0.50/1ea              0.50          1ea  eggs
# ..          ...            ...               ...          ...   ...
# 63        900 g     $0.33/100g              0.33         100g  oats
# 64       1000 g     $0.35/100g              0.35         100g  oats
# 65         1 kg     $0.40/100g              0.40         100g  oats
# 66         1 kg     $0.43/100g              0.43         100g  oats
# 67        680 g     $1.32/100g              1.32         100g  oats
#
# [68 rows x 8 columns]

# %%
final_df.to_csv("food_collection.csv",index=False)
